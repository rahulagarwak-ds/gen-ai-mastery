# %% [markdown]
# # Workout: ruff Linter & Formatter

# %% [markdown]
# ## Drill 1: Check for Issues 🟢
# **Task:** Run ruff to check for linting issues in current directory

# %%
# Your command here
# ruff check .

# %% [markdown]
# ---
# ## Drill 2: Auto-fix Issues 🟢
# **Task:** Run ruff and auto-fix all fixable issues

# %%
# Your command here
# ruff check --fix .

# %% [markdown]
# ---
# ## Drill 3: Format Code 🟢
# **Task:** Format all Python files in the project

# %%
# Your command here
# ruff format .

# %% [markdown]
# ---
# ## Drill 4: Check Format Only 🟢
# **Task:** Check if code is formatted without changing it

# %%
# Your command here
# ruff format --check .

# %% [markdown]
# ---
# ## Drill 5: Configure ruff 🟡
# **Task:** Add this configuration to pyproject.toml:
# - Target Python 3.11
# - Line length 88
# - Enable rules: E, W, F, I, B, UP

# %%
# Write the configuration here (toml format)
config = """
[tool.ruff]
# Your config here
"""
print(config)

# %% [markdown]
# ---
# ## Drill 6: Identify the Issue 🟡
# **Task:** What ruff rules would catch these issues?

# %%
# Issue 1
import os
import sys
import json
# (os is never used)

# Issue 2
def func(items=[]):
    pass

# Issue 3
x = True
y = True
if x:
    if y:
        pass

# Answers:
# 1. Rule: ___
# 2. Rule: ___
# 3. Rule: ___

# %% [markdown]
# ---
# ## Drill 7: Per-file Ignores 🟡
# **Task:** Write config to:
# - Allow unused imports in `__init__.py`
# - Allow asserts in `tests/`

# %%
# Your config here (toml format)
config = """
[tool.ruff.per-file-ignores]
# Your config here
"""
print(config)

# %% [markdown]
# ---
# ## Drill 8: Explain a Rule 🟢
# **Task:** Get detailed explanation of rule E501

# %%
# Your command here
# ruff rule E501

# %% [markdown]
# ---
# ## Self-Check
#
# - [ ] Can run linting and formatting
# - [ ] Can configure ruff in pyproject.toml
# - [ ] Know common rule codes (E, F, I, B)
# - [ ] Can add per-file ignores
