# %% [markdown]
# # Workout: pytest Testing

# %% [markdown]
# ## Drill 1: Basic Test 🟢
# **Task:** Write a test for this function:

# %%
def add(a: int, b: int) -> int:
    return a + b

# Your test here
def test_add():
    pass

# %% [markdown]
# ---
# ## Drill 2: Test Exception 🟡
# **Task:** Write a test that verifies ZeroDivisionError is raised:

# %%
import pytest

def divide(a: int, b: int) -> float:
    return a / b

# Your test here
def test_divide_by_zero():
    pass

# %% [markdown]
# ---
# ## Drill 3: Fixture 🟡
# **Task:** Create a fixture that provides sample user data:

# %%
# conftest.py
import pytest

@pytest.fixture
def sample_user():
    # Return: {"id": 1, "name": "Alice", "email": "alice@test.com"}
    pass

# %% [markdown]
# ---
# ## Drill 4: Parametrize 🟡
# **Task:** Write a parametrized test for email validation:

# %%
import pytest

def is_valid_email(email: str) -> bool:
    return "@" in email and "." in email

# Test cases:
# "user@example.com" -> True
# "invalid" -> False
# "no@dot" -> False

@pytest.mark.parametrize("email,expected", [
    # Add your test cases
])
def test_is_valid_email(email, expected):
    pass

# %% [markdown]
# ---
# ## Drill 5: Mock External Call 🔴
# **Task:** Mock `requests.get` to test this function:

# %%
import requests

def fetch_user(user_id: int) -> dict:
    response = requests.get(f"https://api.example.com/users/{user_id}")
    return response.json()

# Test
from unittest.mock import patch, Mock

def test_fetch_user():
    # Mock requests.get to return {"id": 1, "name": "Alice"}
    pass

# %% [markdown]
# ---
# ## Drill 6: Fixture with Cleanup 🟡
# **Task:** Create a fixture that creates a temp file and removes it after:

# %%
import pytest
import tempfile
import os

@pytest.fixture
def temp_file():
    # Create temp file
    # yield the path
    # Clean up after test
    pass

# %% [markdown]
# ---
# ## Drill 7: Run Commands 🟢
# **Task:** Write the commands to:

# %%
# Run all tests
# pytest

# Run only tests with "user" in name
# pytest -k "user"

# Stop on first failure
# pytest -x

# Run with coverage
# pytest --cov

# %% [markdown]
# ---
# ## Drill 8: Test Class 🟡
# **Task:** Refactor these tests into a class:

# %%
class User:
    def __init__(self, name: str, email: str = None):
        self.name = name
        self.email = email

def test_user_creation():
    user = User("Alice")
    assert user.name == "Alice"

def test_user_email_default():
    user = User("Alice")
    assert user.email is None

# Refactor to:
class TestUser:
    pass

# %% [markdown]
# ---
# ## Self-Check
#
# - [ ] Can write basic assertions
# - [ ] Can test exceptions with `pytest.raises`
# - [ ] Can create and use fixtures
# - [ ] Can parametrize tests
# - [ ] Can mock external dependencies
