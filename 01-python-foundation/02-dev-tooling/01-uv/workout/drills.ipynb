# %% [markdown]
# # Workout: uv Package Manager

# %% [markdown]
# ## Drill 1: Create a Project 🟢
# **Task:** Create a new Python project called "my-api"
#
# **Expected:** Project folder created with pyproject.toml

# %%
# Your command here (run in terminal)
# uv init my-api

# %% [markdown]
# ---
# ## Drill 2: Add Dependencies 🟢
# **Task:** Add fastapi and uvicorn to the project
#
# **Verify:** Check pyproject.toml shows dependencies

# %%
# Your command here
# uv add ...

# %% [markdown]
# ---
# ## Drill 3: Add Dev Dependencies 🟢
# **Task:** Add pytest and ruff as dev dependencies
#
# **Verify:** `uv.lock` file should be updated

# %%
# Your command here
# uv add --dev ...

# %% [markdown]
# ---
# ## Drill 4: Run a Command 🟢
# **Task:** Run pytest using uv (without activating venv)

# %%
# Your command here
# uv run ...

# %% [markdown]
# ---
# ## Drill 5: Pin Python Version 🟡
# **Task:** Pin the project to Python 3.11
#
# **Verify:** .python-version file contains "3.11"

# %%
# Your command here (two steps)
# 1. uv python pin 3.11
# 2. verify with: cat .python-version

# %% [markdown]
# ---
# ## Drill 6: Install from Lock 🟢
# **Task:** Sync environment from lock file (fresh install)

# %%
# Your command here
# uv sync

# %% [markdown]
# ---
# ## Drill 7: Remove a Dependency 🟢
# **Task:** Remove uvicorn from dependencies

# %%
# Your command here
# uv remove ...

# %% [markdown]
# ---
# ## Drill 8: pip Compatibility 🟡
# **Task:** Install requests using pip compatibility mode

# %%
# Your command here
# uv pip install ...

# %% [markdown]
# ---
# ## Self-Check
#
# - [ ] Can create projects with `uv init`
# - [ ] Can add/remove dependencies
# - [ ] Can run commands with `uv run`
# - [ ] Understand the lock file purpose
