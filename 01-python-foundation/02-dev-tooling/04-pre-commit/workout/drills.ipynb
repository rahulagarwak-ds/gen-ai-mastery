# %% [markdown]
# # Workout: pre-commit Hooks

# %% [markdown]
# ## Drill 1: Install pre-commit 🟢
# **Task:** Install pre-commit as a dev dependency

# %%
# Your command here
# uv add --dev pre-commit

# %% [markdown]
# ---
# ## Drill 2: Initialize Hooks 🟢
# **Task:** Install the git hooks after creating config

# %%
# Your command here
# pre-commit install

# %% [markdown]
# ---
# ## Drill 3: Minimal Config 🟡
# **Task:** Create a .pre-commit-config.yaml with ruff hooks:

# %%
# Write the config here (yaml format)
config = """
repos:
  - repo: https://github.com/astral-sh/ruff-pre-commit
    rev: v0.4.0
    hooks:
      # Your hooks here
"""
print(config)

# %% [markdown]
# ---
# ## Drill 4: Run Manually 🟢
# **Task:** Run all hooks on all files

# %%
# Your command here
# pre-commit run --all-files

# %% [markdown]
# ---
# ## Drill 5: Run Specific Hook 🟢
# **Task:** Run only the ruff hook

# %%
# Your command here
# pre-commit run ruff --all-files

# %% [markdown]
# ---
# ## Drill 6: Update Hooks 🟢
# **Task:** Update all hooks to latest versions

# %%
# Your command here
# pre-commit autoupdate

# %% [markdown]
# ---
# ## Drill 7: Full Config 🔴
# **Task:** Write a complete config with:
# - ruff (check + format)
# - trailing-whitespace
# - end-of-file-fixer
# - check-yaml
# - check-added-large-files (max 500kb)
# - no-commit-to-branch (protect main)

# %%
# Write the full config here
config = """
repos:
  # Your full config here
"""
print(config)

# %% [markdown]
# ---
# ## Drill 8: Skip Hooks 🟡
# **Task:** How do you:

# %%
# Skip all hooks for one commit?
# git commit --no-verify

# Skip only mypy hook for one commit?
# SKIP=mypy git commit

# %% [markdown]
# ---
# ## Self-Check
#
# - [ ] Can install and configure pre-commit
# - [ ] Can write .pre-commit-config.yaml
# - [ ] Can run hooks manually
# - [ ] Know how to skip hooks when needed
